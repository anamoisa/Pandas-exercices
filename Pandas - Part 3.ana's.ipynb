# %% [markdown]
# # Mission 1
#
# Display the first 10 rows of the following file: http://bit.ly/imdbratings

# %%
import numpy as np

import pandas as pd

ratings=pd.read_csv('http://bit.ly/imdbratings',sep=',')


ratings.head(10)
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5          8.9  ...  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6          8.9  ...  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7          8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8          8.9  ...  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9          8.9  ...  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
#
# [10 rows x 6 columns]

# %% [markdown]
# # Mission 2
#
# Sort your dataframe in ascending order according to the star_rating column.

# %%
ratings.sort_values(['star_rating'],ascending=True)
# Out:
#      star_rating  ...                                        actors_list
# 978          7.4  ...  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 950          7.4  ...  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 949          7.4  ...  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 948          7.4  ...  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 947          7.4  ...  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...
# ..           ...  ...                                                ...
# 6            8.9  ...  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 3            9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 2            9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 1            9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 0            9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
#
# [979 rows x 6 columns]

# %% [markdown]
# # Mission 3
#
# Answer the question below:
# - What is the median star rating?
# - What is the genre of the most highly rated film?
# - How many (in percentage) of films belong to each genre?

# %%
ratings.median(skipna='star_rating')
# Out:
# star_rating      7.8
# duration       117.0
# dtype: float64

# %%
ratings=pd.read_csv('http://bit.ly/imdbratings',sep=',', index_col='title')
ratings.loc[ratings['star_rating']==ratings["star_rating"].max(), ["genre"]] # pourqoui ça marche pas avec .loc[ratings.tail(1), 'genre']?
# Out:
#                           genre
# title
# The Shawshank Redemption  Crime

# %%
ratings['genre'].value_counts(normalize=True) * 100
# Out:
# Drama        28.396323
# Comedy       15.934627
# Action       13.891726
# Crime        12.665986
# Biography     7.865169
# Adventure     7.660878
# Animation     6.332993
# Horror        2.962206
# Mystery       1.634321
# Western       0.919305
# Sci-Fi        0.510725
# Thriller      0.510725
# Film-Noir     0.306435
# Family        0.204290
# History       0.102145
# Fantasy       0.102145
# Name: genre, dtype: float64

# %% [markdown]
# # Mission 4
#
# Display only the rows with films that belong to the lowest rated genre (based on the average rating of the films in this genre)

# %%
movies=ratings.groupby(by='genre')
movies.mean().min(axis=1).sort_values()
ratings.loc[ratings['genre']=='Thriller']
# Out:
#                            star_rating  ...                                        actors_list
# title                                   ...
# Shadow of a Doubt                  8.0  ...  [u'Teresa Wright', u'Joseph Cotten', u'Macdona...
# Misery                             7.8  ...  [u'James Caan', u'Kathy Bates', u'Richard Farn...
# La piel que habito                 7.6  ...  [u'Antonio Banderas', u'Elena Anaya', u'Jan Co...
# The Man Who Knew Too Much          7.5  ...  [u'James Stewart', u'Doris Day', u'Brenda de B...
# Frenzy                             7.5  ...   [u'Jon Finch', u'Barry Foster', u'Alec McCowen']
#
# [5 rows x 5 columns]

# %% [markdown]
# # Mission 5
#
# Display films which are longer than 200 minutes **and** which belong to a genre with a name containing the letter 'h' (either lower case or upper case)

# %%
movies2=ratings.loc[ratings['duration']>=200]
movies2.loc[movies2['genre'].str.contains('h')| movies2['genre'].str.contains('H')]   #equiv d'un WHERE en sql
# Out:
#            star_rating  ...                                        actors_list
# title                   ...
# Malcolm X          7.7  ...  [u'Denzel Washington', u'Angela Bassett', u'De...
#
# [1 rows x 5 columns]

# %% [markdown]
# # Mission 6
#
# Which actor is mentioned most often in the entire dataframe?

# %%
ratings["actors_list"]=ratings["actors_list"].str.strip("[]") #Pour enlever les crochets
ratings["actors_list"]=ratings["actors_list"].str.split(",") #Pour tout mettre en liste
a = pd.Series(np.concatenate(ratings["actors_list"])) #Pour ne faire qu'une liste
a=a.str.strip("u") # Pour nettoyage
a=a.str.strip("'") # //
a=a.str.strip('"') # //
a.mode()[0]
# Out:
# 'Robert De Niro'
